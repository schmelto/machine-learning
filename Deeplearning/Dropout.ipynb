# %% [markdown]
# <a href="https://colab.research.google.com/github/schmelto/machine-learning/blob/main/Deeplearning/Dropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dropout
# ## Version Selection and Imports

# %%
# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

if not tf.test.is_gpu_available():
    print("No GPU was detected. CNNs can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware accelerator.")
# Out:
# WARNING:tensorflow:From <ipython-input-1-9d3757df4c1b>:6: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense, Activation, Input, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from scipy.stats import reciprocal
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# jupyters magic command
# %matplotlib inline

# %% [markdown]
# ## Helpers

# %%
import typing

def plot_images(images: "DatasetV1Adapter", class_names: typing.List[str]) -> None:
    plt.figure(figsize=(12, 10))
    index = 0
    for image, label in images:
        index += 1
        plt.subplot(3, 3, index)
        plt.imshow(image)
        plt.title("Class: {}".format(class_names[label]))
        plt.axis("off")

def plot_learning_curve(
    title: str, x: int, y: int, y_test: int, ylim: float = 0.6
) -> None:
    plt.figure()
    plt.title(title)
    axes = plt.gca()
    axes.set_ylim([ylim, 1])
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    train_sizes = x
    train_scores = y
    test_scores = y_test

    plt.grid()

    plt.plot(
        train_sizes,
        train_scores,
        "o-",
        color=(177 / 255, 6 / 255, 58 / 255),
        label="Training accuracy",
    )
    plt.plot(
        train_sizes,
        test_scores,
        "o-",
        color=(246 / 255, 168 / 255, 0),
        label="Validation accuracy",
    )

    plt.legend(loc="best")


def plot_history(title: str, history: "History", ylim: float = 0.6) -> None:
    y = history.history["accuracy"]
    y_test = history.history["val_accuracy"]
    plot_learning_curve(title, np.arange(1, 1 + len(y)), y, y_test, ylim)

# %% [markdown]
# ## Loading and Preprocessing

# %%
# resize the images to a uniform size
def preprocess(image, label):
    resized_image = tf.image.resize(image, [224, 224])
    return resized_image, label

# %%
# download the dataset with labels and with information about the data
data, info = tfds.load("tf_flowers", as_supervised=True, with_info=True)

# print the most important information
dataset_size = info.splits['train'].num_examples
print('dataset size: ', dataset_size)
class_names = info.features['label'].names
print('class names: ', class_names)
n_classes = info.features['label'].num_classes
print('number of classes: ', n_classes)

batch_size = 32

try:
  train_data = tfds.load('tf_flowers', split="train[:80%]", as_supervised=True)
  test_data = tfds.load('tf_flowers', split="train[80%:100%]", as_supervised=True)
  train_data = train_data.shuffle(1000).map(preprocess).batch(batch_size).prefetch(1)
  test_data = test_data.map(preprocess).batch(batch_size).prefetch(1)
except(Exception):
  # split the data into train and test data with a 8:2 ratio
  train_split, test_split = tfds.Split.TRAIN.subsplit([8, 2])
  train_data = tfds.load('tf_flowers', split=train_split, as_supervised=True)
  test_data = tfds.load('tf_flowers', split=test_split, as_supervised=True)
  train_data = train_data.shuffle(1000).map(preprocess).batch(batch_size).prefetch(1)
  test_data = test_data.map(preprocess).batch(batch_size).prefetch(1)
# Out:
# Downloading and preparing dataset tf_flowers/3.0.1 (download: 218.21 MiB, generated: 221.83 MiB, total: 440.05 MiB) to /root/tensorflow_datasets/tf_flowers/3.0.1...
# WARNING:absl:Dataset tf_flowers is hosted on GCS. It will automatically be downloaded to your
# local data directory. If you'd instead prefer to read directly from our public
# GCS bucket (recommended if you're running on GCP), you can instead pass
# `try_gcs=True` to `tfds.load` or set `data_dir=gs://tfds-data/datasets`.
# HBox(children=(FloatProgress(value=0.0, description='Dl Completed...', max=5.0, style=ProgressStyle(descriptio…
# Dataset tf_flowers downloaded and prepared to /root/tensorflow_datasets/tf_flowers/3.0.1. Subsequent calls will reuse this data.
# dataset size:  3670
# class names:  ['dandelion', 'daisy', 'tulips', 'sunflowers', 'roses']
# number of classes:  5

# %%
# show some images from the dataset
plot_images(train_data.unbatch().take(9).map(lambda x, y: (x / 255, y)), class_names)

# %% [markdown]
# ## Model Definition and Training

# %%
# model without Dropout
learning_rate=0.0001
momentum=0.9
decay=0.01
dense_neurons=1000
n_filters=32
first_kernel_size=(7,7)

activation='elu'

# input size of images must be 224x224 with RGB color
input_layer = Input(shape=(224, 224, 3))

# Convolutional Neural Network
# It consists of 5 stacked Convolutional Layers with Max Pooling
model = Conv2D(filters=n_filters, kernel_size=(7,7), activation=activation)(input_layer)
model = MaxPooling2D((2,2))(model)

for i in range(2, 5):
  model = Conv2D(
      filters = i * n_filters, 
      kernel_size=(3,3), 
      activation=activation
    )(model)
  model = MaxPooling2D((2,2))(model)

model = Conv2D(filters = 5 * n_filters, 
  kernel_size=(3,3), 
  activation=activation, 
  padding='same'
)(model)
model = MaxPooling2D((2,2))(model)

# Fully-Connected-Classifier
model = Flatten()(model)
model = Dense(dense_neurons, activation=activation)(model)

model = Dense(dense_neurons / 2, activation='tanh')(model)

# Output Layer
output = Dense(n_classes, activation="softmax")(model)

CNN_model = Model(input_layer, output)

# Compiling model
optimizer = keras.optimizers.SGD(lr=learning_rate, momentum=momentum, decay=decay)
CNN_model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
            metrics=["accuracy"])

# %%
CNN_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 218, 218, 32)      4736
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 109, 109, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 107, 107, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 53, 53, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 51, 51, 96)        55392
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 96)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 23, 23, 128)       110720
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 160)       184480
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 160)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4000)              0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              4001000
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               500500
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 2505
# =================================================================
# Total params: 4,877,829
# Trainable params: 4,877,829
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model without Dropout
history = CNN_model.fit(
    train_data,
    epochs=100,
    validation_data=test_data
)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 12s 57ms/step - loss: 1.5849 - accuracy: 0.2994 - val_loss: 1.2945 - val_accuracy: 0.4441
# Epoch 2/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.2510 - accuracy: 0.4868 - val_loss: 1.1845 - val_accuracy: 0.5150
# Epoch 3/100
# 92/92 [==============================] - 4s 42ms/step - loss: 1.1492 - accuracy: 0.5294 - val_loss: 1.1695 - val_accuracy: 0.5259
# Epoch 4/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.1207 - accuracy: 0.5395 - val_loss: 1.1071 - val_accuracy: 0.5681
# Epoch 5/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.0558 - accuracy: 0.5796 - val_loss: 1.0878 - val_accuracy: 0.5804
# Epoch 6/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.0068 - accuracy: 0.6131 - val_loss: 1.0726 - val_accuracy: 0.5845
# Epoch 7/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.9856 - accuracy: 0.6274 - val_loss: 1.0586 - val_accuracy: 0.5926
# Epoch 8/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.9808 - accuracy: 0.6260 - val_loss: 1.0707 - val_accuracy: 0.5708
# Epoch 9/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.9626 - accuracy: 0.6353 - val_loss: 1.0461 - val_accuracy: 0.5763
# Epoch 10/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.9278 - accuracy: 0.6642 - val_loss: 1.0512 - val_accuracy: 0.5858
# Epoch 11/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.9189 - accuracy: 0.6644 - val_loss: 1.0429 - val_accuracy: 0.5817
# Epoch 12/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.9036 - accuracy: 0.6757 - val_loss: 1.0343 - val_accuracy: 0.5886
# Epoch 13/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.9192 - accuracy: 0.6653 - val_loss: 1.0309 - val_accuracy: 0.5940
# Epoch 14/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.9050 - accuracy: 0.6780 - val_loss: 1.0295 - val_accuracy: 0.6022
# Epoch 15/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.9145 - accuracy: 0.6603 - val_loss: 1.0281 - val_accuracy: 0.5886
# Epoch 16/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8816 - accuracy: 0.6848 - val_loss: 1.0255 - val_accuracy: 0.5926
# Epoch 17/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8672 - accuracy: 0.6965 - val_loss: 1.0287 - val_accuracy: 0.5831
# Epoch 18/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8743 - accuracy: 0.6854 - val_loss: 1.0253 - val_accuracy: 0.5926
# Epoch 19/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8721 - accuracy: 0.6776 - val_loss: 1.0212 - val_accuracy: 0.6035
# Epoch 20/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8574 - accuracy: 0.6928 - val_loss: 1.0200 - val_accuracy: 0.5886
# Epoch 21/100
# 92/92 [==============================] - 4s 46ms/step - loss: 0.8480 - accuracy: 0.7012 - val_loss: 1.0189 - val_accuracy: 0.5899
# Epoch 22/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8480 - accuracy: 0.7002 - val_loss: 1.0201 - val_accuracy: 0.5817
# Epoch 23/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8356 - accuracy: 0.7058 - val_loss: 1.0241 - val_accuracy: 0.5886
# Epoch 24/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8286 - accuracy: 0.7067 - val_loss: 1.0189 - val_accuracy: 0.5967
# Epoch 25/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8563 - accuracy: 0.6979 - val_loss: 1.0164 - val_accuracy: 0.5981
# Epoch 26/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8438 - accuracy: 0.7036 - val_loss: 1.0138 - val_accuracy: 0.5886
# Epoch 27/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8495 - accuracy: 0.7023 - val_loss: 1.0107 - val_accuracy: 0.5967
# Epoch 28/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8448 - accuracy: 0.7013 - val_loss: 1.0133 - val_accuracy: 0.5926
# Epoch 29/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8230 - accuracy: 0.7187 - val_loss: 1.0125 - val_accuracy: 0.5845
# Epoch 30/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8122 - accuracy: 0.7221 - val_loss: 1.0107 - val_accuracy: 0.5981
# Epoch 31/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8335 - accuracy: 0.7112 - val_loss: 1.0152 - val_accuracy: 0.5926
# Epoch 32/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8240 - accuracy: 0.7167 - val_loss: 1.0109 - val_accuracy: 0.5913
# Epoch 33/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8385 - accuracy: 0.7047 - val_loss: 1.0080 - val_accuracy: 0.5967
# Epoch 34/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8337 - accuracy: 0.7087 - val_loss: 1.0104 - val_accuracy: 0.5967
# Epoch 35/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8120 - accuracy: 0.7206 - val_loss: 1.0061 - val_accuracy: 0.5981
# Epoch 36/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8068 - accuracy: 0.7212 - val_loss: 1.0091 - val_accuracy: 0.5981
# Epoch 37/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8269 - accuracy: 0.7073 - val_loss: 1.0091 - val_accuracy: 0.5981
# Epoch 38/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8281 - accuracy: 0.7116 - val_loss: 1.0065 - val_accuracy: 0.6035
# Epoch 39/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8129 - accuracy: 0.7296 - val_loss: 1.0066 - val_accuracy: 0.5954
# Epoch 40/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8049 - accuracy: 0.7258 - val_loss: 1.0059 - val_accuracy: 0.5981
# Epoch 41/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8184 - accuracy: 0.7236 - val_loss: 1.0099 - val_accuracy: 0.6049
# Epoch 42/100
# 92/92 [==============================] - 4s 46ms/step - loss: 0.8201 - accuracy: 0.7175 - val_loss: 1.0048 - val_accuracy: 0.5940
# Epoch 43/100
# 92/92 [==============================] - 4s 46ms/step - loss: 0.7927 - accuracy: 0.7358 - val_loss: 1.0035 - val_accuracy: 0.5967
# Epoch 44/100
# 92/92 [==============================] - 4s 43ms/step - loss: 0.7997 - accuracy: 0.7356 - val_loss: 1.0058 - val_accuracy: 0.5940
# Epoch 45/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8268 - accuracy: 0.7213 - val_loss: 1.0060 - val_accuracy: 0.5886
# Epoch 46/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7917 - accuracy: 0.7352 - val_loss: 1.0035 - val_accuracy: 0.6022
# Epoch 47/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.7885 - accuracy: 0.7305 - val_loss: 1.0045 - val_accuracy: 0.6022
# Epoch 48/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.7961 - accuracy: 0.7300 - val_loss: 1.0021 - val_accuracy: 0.5954
# Epoch 49/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7928 - accuracy: 0.7318 - val_loss: 1.0038 - val_accuracy: 0.6063
# Epoch 50/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.7745 - accuracy: 0.7401 - val_loss: 1.0016 - val_accuracy: 0.6090
# Epoch 51/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7994 - accuracy: 0.7279 - val_loss: 1.0025 - val_accuracy: 0.6008
# Epoch 52/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8036 - accuracy: 0.7343 - val_loss: 1.0034 - val_accuracy: 0.5954
# Epoch 53/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7874 - accuracy: 0.7350 - val_loss: 1.0020 - val_accuracy: 0.5967
# Epoch 54/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7902 - accuracy: 0.7251 - val_loss: 1.0000 - val_accuracy: 0.5995
# Epoch 55/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7858 - accuracy: 0.7349 - val_loss: 0.9998 - val_accuracy: 0.6008
# Epoch 56/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7859 - accuracy: 0.7474 - val_loss: 1.0030 - val_accuracy: 0.6063
# Epoch 57/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.7804 - accuracy: 0.7424 - val_loss: 0.9995 - val_accuracy: 0.5940
# Epoch 58/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.7874 - accuracy: 0.7367 - val_loss: 0.9999 - val_accuracy: 0.6090
# Epoch 59/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.7829 - accuracy: 0.7488 - val_loss: 0.9988 - val_accuracy: 0.6090
# Epoch 60/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7895 - accuracy: 0.7407 - val_loss: 1.0000 - val_accuracy: 0.6008
# Epoch 61/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7834 - accuracy: 0.7346 - val_loss: 0.9981 - val_accuracy: 0.6049
# Epoch 62/100
# 92/92 [==============================] - 4s 43ms/step - loss: 0.7782 - accuracy: 0.7426 - val_loss: 0.9998 - val_accuracy: 0.6117
# Epoch 63/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.7882 - accuracy: 0.7355 - val_loss: 0.9995 - val_accuracy: 0.5981
# Epoch 64/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7579 - accuracy: 0.7469 - val_loss: 0.9969 - val_accuracy: 0.6076
# Epoch 65/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7622 - accuracy: 0.7451 - val_loss: 0.9973 - val_accuracy: 0.5995
# Epoch 66/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7692 - accuracy: 0.7432 - val_loss: 0.9969 - val_accuracy: 0.6022
# Epoch 67/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7690 - accuracy: 0.7496 - val_loss: 0.9953 - val_accuracy: 0.6035
# Epoch 68/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.7724 - accuracy: 0.7490 - val_loss: 0.9956 - val_accuracy: 0.6008
# Epoch 69/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.
100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.7455 - accuracy: 0.7567 - val_loss: 0.9904 - val_accuracy: 0.6076
# Epoch 100/100
# 92/92 [==============================] - 4s 43ms/step - loss: 0.7534 - accuracy: 0.7624 - val_loss: 0.9906 - val_accuracy: 0.6104

# %%
from tensorflow.keras.layers import Dropout

# model with Dropout
learning_rate=0.0001
momentum=0.9
decay=0.001
dense_neurons=1000
n_filters=32
first_kernel_size=(7,7)

activation='elu'

# input size of images must be 224x224 with RGB color
input_layer = Input(shape=(224, 224, 3))

# Convolutional Neural Network
# It consists of 5 stacked Convolutional Layers with Max Pooling
model = Conv2D(
    filters=n_filters, 
    kernel_size=(7,7), 
    activation=activation
    )(input_layer)
model = MaxPooling2D((2,2))(model)

for i in range(2, 5):
  model = Conv2D(
      filters = i * n_filters, 
      kernel_size=(3,3), 
      activation=activation
    )(model)
  model = MaxPooling2D((2,2))(model)

model = Conv2D(filters = 5 * n_filters, 
  kernel_size=(3,3), 
  activation=activation, 
  padding='same'
)(model)
model = MaxPooling2D((2,2))(model)

# Fully-Connected-Classifier
model = Flatten()(model)
model = Dense(dense_neurons, activation=activation)(model)
model = Dropout(0.5)(model)

model = Dense(dense_neurons / 2, activation='tanh')(model)
model = Dropout(0.5)(model)

# Output Layer
output = Dense(n_classes, activation="softmax")(model)

CNN_Dropout_model = Model(input_layer, output)

# Compiling model
optimizer = keras.optimizers.SGD(
    lr=learning_rate, 
    momentum=momentum, 
    decay=decay
    )
CNN_Dropout_model.compile(
    loss="sparse_categorical_crossentropy", 
    optimizer=optimizer,
    metrics=["accuracy"]
    )

# %%
# Train the model with Dropout
history_dropout = CNN_Dropout_model.fit(
    train_data,
    epochs=100,
    validation_data=test_data
)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 5s 43ms/step - loss: 2.5747 - accuracy: 0.2032 - val_loss: 1.8144 - val_accuracy: 0.2357
# Epoch 2/100
# 92/92 [==============================] - 4s 41ms/step - loss: 2.4448 - accuracy: 0.1950 - val_loss: 1.6563 - val_accuracy: 0.2371
# Epoch 3/100
# 92/92 [==============================] - 4s 41ms/step - loss: 2.4984 - accuracy: 0.1927 - val_loss: 1.6394 - val_accuracy: 0.2057
# Epoch 4/100
# 92/92 [==============================] - 4s 41ms/step - loss: 2.3977 - accuracy: 0.2203 - val_loss: 1.7885 - val_accuracy: 0.2275
# Epoch 5/100
# 92/92 [==============================] - 4s 41ms/step - loss: 2.3049 - accuracy: 0.2266 - val_loss: 1.6553 - val_accuracy: 0.2098
# Epoch 6/100
# 92/92 [==============================] - 4s 41ms/step - loss: 2.3240 - accuracy: 0.2166 - val_loss: 1.5998 - val_accuracy: 0.2997
# Epoch 7/100
# 92/92 [==============================] - 4s 41ms/step - loss: 2.2879 - accuracy: 0.2224 - val_loss: 1.5276 - val_accuracy: 0.3188
# Epoch 8/100
# 92/92 [==============================] - 4s 41ms/step - loss: 2.2420 - accuracy: 0.2143 - val_loss: 1.5329 - val_accuracy: 0.2970
# Epoch 9/100
# 92/92 [==============================] - 4s 41ms/step - loss: 2.1073 - accuracy: 0.2661 - val_loss: 1.4333 - val_accuracy: 0.3678
# Epoch 10/100
# 92/92 [==============================] - 4s 41ms/step - loss: 2.0299 - accuracy: 0.2759 - val_loss: 1.3913 - val_accuracy: 0.4183
# Epoch 11/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.9235 - accuracy: 0.3054 - val_loss: 1.3662 - val_accuracy: 0.4237
# Epoch 12/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.8710 - accuracy: 0.3303 - val_loss: 1.2143 - val_accuracy: 0.4877
# Epoch 13/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.8057 - accuracy: 0.3317 - val_loss: 1.2116 - val_accuracy: 0.4959
# Epoch 14/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.7612 - accuracy: 0.3634 - val_loss: 1.2944 - val_accuracy: 0.5041
# Epoch 15/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.7367 - accuracy: 0.3732 - val_loss: 1.2313 - val_accuracy: 0.5232
# Epoch 16/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.6756 - accuracy: 0.4108 - val_loss: 1.2010 - val_accuracy: 0.5054
# Epoch 17/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.6175 - accuracy: 0.4129 - val_loss: 1.1763 - val_accuracy: 0.5313
# Epoch 18/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.5751 - accuracy: 0.4276 - val_loss: 1.1464 - val_accuracy: 0.5259
# Epoch 19/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.5550 - accuracy: 0.4506 - val_loss: 1.1733 - val_accuracy: 0.5191
# Epoch 20/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.5082 - accuracy: 0.4492 - val_loss: 1.1353 - val_accuracy: 0.5545
# Epoch 21/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.4851 - accuracy: 0.4520 - val_loss: 1.1519 - val_accuracy: 0.5477
# Epoch 22/100
# 92/92 [==============================] - 4s 42ms/step - loss: 1.5147 - accuracy: 0.4485 - val_loss: 1.1468 - val_accuracy: 0.5681
# Epoch 23/100
# 92/92 [==============================] - 4s 46ms/step - loss: 1.5022 - accuracy: 0.4595 - val_loss: 1.1741 - val_accuracy: 0.5599
# Epoch 24/100
# 92/92 [==============================] - 4s 44ms/step - loss: 1.4727 - accuracy: 0.4610 - val_loss: 1.1497 - val_accuracy: 0.5749
# Epoch 25/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.3838 - accuracy: 0.4959 - val_loss: 1.1211 - val_accuracy: 0.5831
# Epoch 26/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.3466 - accuracy: 0.5005 - val_loss: 1.0812 - val_accuracy: 0.5913
# Epoch 27/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.3385 - accuracy: 0.5057 - val_loss: 1.0666 - val_accuracy: 0.5995
# Epoch 28/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.3167 - accuracy: 0.5020 - val_loss: 1.1171 - val_accuracy: 0.5872
# Epoch 29/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.3264 - accuracy: 0.5162 - val_loss: 1.0547 - val_accuracy: 0.6008
# Epoch 30/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.3112 - accuracy: 0.5125 - val_loss: 1.0814 - val_accuracy: 0.6008
# Epoch 31/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.3514 - accuracy: 0.5044 - val_loss: 1.0456 - val_accuracy: 0.6049
# Epoch 32/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.2715 - accuracy: 0.5264 - val_loss: 1.0555 - val_accuracy: 0.6185
# Epoch 33/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.3041 - accuracy: 0.5228 - val_loss: 1.0365 - val_accuracy: 0.6172
# Epoch 34/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.2699 - accuracy: 0.5205 - val_loss: 1.0774 - val_accuracy: 0.5940
# Epoch 35/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.2083 - accuracy: 0.5387 - val_loss: 1.0530 - val_accuracy: 0.6076
# Epoch 36/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.2336 - accuracy: 0.5228 - val_loss: 1.0245 - val_accuracy: 0.6158
# Epoch 37/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.2768 - accuracy: 0.5228 - val_loss: 1.0063 - val_accuracy: 0.6226
# Epoch 38/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.1771 - accuracy: 0.5667 - val_loss: 1.0632 - val_accuracy: 0.6104
# Epoch 39/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.1424 - accuracy: 0.5700 - val_loss: 1.0353 - val_accuracy: 0.6349
# Epoch 40/100
# 92/92 [==============================] - 4s 42ms/step - loss: 1.1559 - accuracy: 0.5660 - val_loss: 0.9922 - val_accuracy: 0.6240
# Epoch 41/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.1760 - accuracy: 0.5557 - val_loss: 0.9889 - val_accuracy: 0.6349
# Epoch 42/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.1470 - accuracy: 0.5558 - val_loss: 0.9980 - val_accuracy: 0.6213
# Epoch 43/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.1617 - accuracy: 0.5481 - val_loss: 0.9698 - val_accuracy: 0.6362
# Epoch 44/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.1061 - accuracy: 0.5792 - val_loss: 0.9798 - val_accuracy: 0.6322
# Epoch 45/100
# 92/92 [==============================] - 4s 41ms/step - loss: 1.
100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.9062 - accuracy: 0.6420 - val_loss: 0.8702 - val_accuracy: 0.6757
# Epoch 76/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.9265 - accuracy: 0.6334 - val_loss: 0.8787 - val_accuracy: 0.6676
# Epoch 77/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.9046 - accuracy: 0.6385 - val_loss: 0.8534 - val_accuracy: 0.6866
# Epoch 78/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.9082 - accuracy: 0.6614 - val_loss: 0.8592 - val_accuracy: 0.6744
# Epoch 79/100
# 92/92 [==============================] - 4s 44ms/step - loss: 0.8625 - accuracy: 0.6677 - val_loss: 0.8710 - val_accuracy: 0.6717
# Epoch 80/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8553 - accuracy: 0.6624 - val_loss: 0.8987 - val_accuracy: 0.6703
# Epoch 81/100
# 92/92 [==============================] - 4s 43ms/step - loss: 0.8776 - accuracy: 0.6589 - val_loss: 0.8723 - val_accuracy: 0.6744
# Epoch 82/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8568 - accuracy: 0.6627 - val_loss: 0.9073 - val_accuracy: 0.6540
# Epoch 83/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8538 - accuracy: 0.6726 - val_loss: 0.8641 - val_accuracy: 0.6744
# Epoch 84/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8722 - accuracy: 0.6655 - val_loss: 0.8651 - val_accuracy: 0.6785
# Epoch 85/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8790 - accuracy: 0.6529 - val_loss: 0.8842 - val_accuracy: 0.6853
# Epoch 86/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8767 - accuracy: 0.6647 - val_loss: 0.8458 - val_accuracy: 0.6839
# Epoch 87/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8440 - accuracy: 0.6746 - val_loss: 0.8419 - val_accuracy: 0.6894
# Epoch 88/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8440 - accuracy: 0.6802 - val_loss: 0.8349 - val_accuracy: 0.6948
# Epoch 89/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8294 - accuracy: 0.6841 - val_loss: 0.8481 - val_accuracy: 0.6853
# Epoch 90/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8468 - accuracy: 0.6658 - val_loss: 0.8472 - val_accuracy: 0.6880
# Epoch 91/100
# 92/92 [==============================] - 4s 42ms/step - loss: 0.8797 - accuracy: 0.6688 - val_loss: 0.8378 - val_accuracy: 0.6812
# Epoch 92/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8448 - accuracy: 0.6843 - val_loss: 0.8374 - val_accuracy: 0.6894
# Epoch 93/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8512 - accuracy: 0.6753 - val_loss: 0.8505 - val_accuracy: 0.6812
# Epoch 94/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8199 - accuracy: 0.6901 - val_loss: 0.8378 - val_accuracy: 0.6880
# Epoch 95/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8535 - accuracy: 0.6676 - val_loss: 0.8406 - val_accuracy: 0.6880
# Epoch 96/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8529 - accuracy: 0.6703 - val_loss: 0.8287 - val_accuracy: 0.7098
# Epoch 97/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8696 - accuracy: 0.6579 - val_loss: 0.8296 - val_accuracy: 0.7030
# Epoch 98/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8182 - accuracy: 0.6794 - val_loss: 0.8282 - val_accuracy: 0.6907
# Epoch 99/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8256 - accuracy: 0.6778 - val_loss: 0.8524 - val_accuracy: 0.6907
# Epoch 100/100
# 92/92 [==============================] - 4s 41ms/step - loss: 0.8298 - accuracy: 0.6789 - val_loss: 0.8467 - val_accuracy: 0.6907

# %% [markdown]
# # Visualize Results

# %%
plot_history('CNN without Dropout', history, 0)

# validation accuracy might be sometimes higher than training accuracy due to 2 reasons:
#     - train acc is calculated as the mean of the whole epoch, test acc is calculated after each epoch
#       (where the model is better than in the mid of the epoch)
#     - when you use e.g. Dropout, the behavior at training time is different

# %%
plot_history('CNN with Dropout', history_dropout, 0)
